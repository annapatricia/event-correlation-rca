# %% [markdown]
# <a href="https://colab.research.google.com/github/annapatricia/event-correlation-rca/blob/main/notebooks/RCA_Event_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Event Correlation & Root Cause Analysis")
print("Projeto de Machine Learning")
# Out:
# Event Correlation & Root Cause Analysis
# Projeto de Machine Learning

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import networkx

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
print("NetworkX:", networkx.__version__)
# Out:
# Pandas: 2.2.3
# NumPy: 2.1.3
# Scikit-learn: 1.6.1
# Matplotlib: 3.10.0
# NetworkX: 3.6.1
